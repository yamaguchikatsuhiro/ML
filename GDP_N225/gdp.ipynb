# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
gdp = pd.read_csv("/content/drive/MyDrive/GDP_N225/datasets/gaku-mfy2322.csv", encoding="shift-jis")

# %%
gdp.head()
# Out:
#                    名目年度                 Unnamed: 1          Unnamed: 2  \
# 0  Nominal, Fiscal Year                        NaN                 NaN
# 1                   NaN                 国内総生産(支出側)            民間最終消費支出
# 2                   NaN                        NaN                 NaN
# 3                   NaN                        NaN                 NaN
# 4                   NaN  GDP(Expenditure Approach)  PrivateConsumption
#
#                  Unnamed: 3             Unnamed: 4  \
# 0                       NaN                    NaN
# 1                       NaN                    NaN
# 2                  家計最終消費支出                    NaN
# 3                       NaN             除く持ち家の帰属家賃
# 4  Consumption ofHouseholds  ExcludingImputed Rent
#
#                      Unnamed: 5                   Unnamed: 6  \
# 0                           NaN                          NaN
# 1                          民間住宅                       民間企業設備
# ...

# %%
gdp = gdp[["名目年度", "Unnamed: 1"]]
gdp = gdp.iloc[6:, :].reset_index(drop=True)
gdp = gdp.iloc[:-1]
gdp = gdp.rename(columns={"名目年度": "year", "Unnamed: 1": "Billion Yen"})

# %%
gdp["year"] = gdp["year"].str[:4]

# %%
gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   year         29 non-null     object
#  1   Billion Yen  29 non-null     object
# dtypes: object(2)
# memory usage: 592.0+ bytes

# %%
gdp["year"] = gdp["year"].astype(np.int64)

# %%
gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   year         29 non-null     int64
#  1   Billion Yen  29 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 592.0+ bytes

# %%
gdp.head()
# Out:
#    year Billion Yen
# 0  1994  511,958.8
# 1  1995  525,299.5
# 2  1996  538,659.6
# 3  1997  542,508.0
# 4  1998  534,564.1

# %%
gdp["Billion Yen"] = gdp["Billion Yen"].str.replace(",","").astype(np.float64)
gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   year         29 non-null     int64
#  1   Billion Yen  29 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 592.0 bytes

# %%
gdp.head()
# Out:
#    year  Billion Yen
# 0  1994     511958.8
# 1  1995     525299.5
# 2  1996     538659.6
# 3  1997     542508.0
# 4  1998     534564.1

# %%
gdp.to_csv("/content/drive/MyDrive/GDP_N225/datasets/gdp.csv")
